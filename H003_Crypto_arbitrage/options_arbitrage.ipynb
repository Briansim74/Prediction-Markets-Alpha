# %%
import pandas as pd

arb_df = pd.read_parquet("vertical_arb_df.parquet")
arb_df
# Out:
#   currency event_type direction  lower_strike  \
# 0      ETH      touch        up        5500.0
#
#                                      lower_question lower_id lower_side  \
# 0  Will Ethereum reach $5,500 by December 31, 2026?   701545        Yes
#
#    lower_price  lower_cost  higher_strike  \
# 0        0.031    0.033103         6000.0
#
#                                     higher_question higher_id higher_side  \
# 0  Will Ethereum reach $6,000 by December 31, 2026?    701544          No
#
#    higher_price  higher_cost  total_cost  guaranteed_profit
# 0          0.96     0.962688    0.995791           0.004209
